# %% [markdown]
# # Notebook 8 - Knowledge Representation (KR)

# %% [markdown]
# CSI4106 Artificial Intelligence  \
# Fall 2021 \
# Version 1 (2020) prepared by Julian Templeton and Caroline Barrière.  Version 2 (2021) revised by Caroline Barrière.

# %% [markdown]
# ***INTRODUCTION***:
#
# When reading text, understanding the type of entities within the text helps to infer additional information about the entity. For example, if a text mentions *Canada*, knowing that it is a GPE (geopolitical entity), already indicates to us that this entity has a supercify, a population, etc. Through the use of Named Entity Recognition (NER), we are able to determine whether an entity is a Person, Organization, Country, ...
#
# When exploring text online, we also occassionally see entities have clickable links to webpages with more information on the entity. This is a form of enhancement of the text to allow readers to easily access the information needed to understand each entity from the text and its content.  If we take the example of Canada again, if we transform it into [Canada](https://en.wikipedia.org/wiki/Canada), using entity linking we access more information.
#
# In this notebook we will be revisiting the Covid-19 related news dataset from notebook 7 to explore how we can improve spaCy's NER and enhance the text from the news articles through the use of entity linking. This will be done in three parts:
#
# (1) we explore the results of spaCy's NER  \
# (2) we use text coherence for post-processing spaCy's NER results \
# (3) we perform text enhancement with entity linking.
#
# This notebook uses libraries that have been used in previous notebooks, including spaCy and pandas.

# %% [markdown]
# ***HOMEWORK***:
# Go through the notebook by running each cell, one at a time.
# Look for **(TO DO)** for the tasks that you need to perform. Do not edit the code outside of the questions which you are asked to answer unless specifically asked. Once you're done, sign the notebook (at the end of the notebook), rename it to *StudentNum-LastName-Notebook8.ipynb* and submit it.
#
# *The notebook will be marked on 30.
# Each **(TO DO)** has a number of points associated with it.*
# ***

# %%
# Before starting we will import every module that we will be using
import spacy
import pandas as pd

# %%
# The core spacy object can be used for tokenization, lemmatization, POS Tagging, NER, ...
# Note that this is specifically for the English language and requires the English package to be installed
# via pip to work as intended.

# sp = spacy.load('en')

# If the above causes an error after installing the package 
# then install the package as below
# !spacy download en_core_web_sm
sp = spacy.load('en_core_web_sm')

# %% [markdown]
# Similarly to the last notebook, the dataset is provided on Brightspace (Module 8) along with this notebook, but details regarding Covid-19 news dataset can be found [here](https://www.kaggle.com/ryanxjhan/cbc-news-coronavirus-articles-march-26?select=news.csv). The first thing that we will do, as usual, is load the file into a pandas dataframe.

# %%
# Read the dataset, show top ten rows
df = pd.read_csv("news.csv")
df.head(10)
# Out:
#   Unnamed: 0                                            authors  \
# 0          0                                                 []
# 1          1                                                 []
# 2          2                             ['The Canadian Press']
# 3          3                                                 []
# 4          4                                                 []
# 5          5  ['Senior Writer', 'Chris Arsenault Is A Senior...
# 6          6                                       ['Cbc News']
# 7          7                                       ['Cbc News']
# 8          8  ['Senior Writer', "Adam Miller Is Senior Digit...
# 9          9                                ['Thomson Reuters']
#
#                                                title      publish_date  \
# 0  'More vital now:' Gay-straight alliances go vi...   2020-05-03 1:30
# 1  Scientists aim to 'see' invisible transmission...   2020-05-02 8:00
# 2  Coronavirus: What's happening in Canada and ar...  2020-05-02 11:28
# 3  B.C. announces 26 new coronavirus cases, new c...  2020-05-02 18:45
# 4  B.C. announces 26 new coronavirus cases, new c...  2020-05-02 18:45
# 5  Brazil has the most confirmed COVID-19 cases i...   2020-05-02 8:00
# 6   The latest on the coronavirus outbreak for May 1  2020-05-01 20:43
# 7  Coronavirus: What's happening in Canada and ar...  2020-05-01 11:51
# 8  Did the WHO mishandle the global coronavirus p...   2020-04-30 8:00
# 9  Armed people in Michigan's legislature protest...  2020-04-30 21:37
#
#                                          description  \
# 0  Lily Overacker and Laurell Pallot start each g...
# 1  Some researchers aim to learn more about how t...
# 2  Canada's chief public health officer struck an...
# 3  B.C. provincial health officer Dr. Bonnie Henr...
# 4  B.C. provincial health officer Dr. Bonnie Henr...
# 5  From describing coronavirus as a "little flu,"...
# 6  The latest on the coronavirus outbreak from CB...
# 7  Nova Scotia announced Friday it is immediately...
# 8  The World Health Organization has come under f...
# 9  Hundreds of protesters, some armed, gathered a...
#
#                                                 text  \
# 0  Lily Overacker and Laurell Pallot start each g...
# 1  This is an excerpt from Second Opinion, a week...
# 2  The latest:  The lives behind the numbers: Wha...
# 3  B.C. provincial health officer Dr. Bonnie Henr...
# 4  B.C. provincial health officer Dr. Bonnie Henr...
# 5  With infection rates spiralling, some big city...
# 6    Coronavirus Brief (CBC)  Canada is officiall...
# 7  The latest:  The lives behind the numbers: Wha...
# 8  The World Health Organization has come under f...
# 9  Hundreds of protesters, some armed, gathered a...
#
#                                                  url
# 0  https://www.cbc.ca/news/canada/calgary/gay-str...
# 1  https://www.cbc.ca/news/technology/droplet-tra...
# 2  https://www.cbc.ca/news/canada/coronavirus-cov...
# 3  https://www.cbc.ca/news/canada/british-columbi...
# 4  https://www.cbc.ca/news/canada/british-columbi...
# 5  https://www.cbc.ca/news/world/brazil-has-the-m...
# 6  https://www.cbc.ca/news/the-latest-on-the-coro...
# 7  https://www.cbc.ca/news/canada/coronavirus-cov...
# 8  https://www.cbc.ca/news/health/coronavirus-who...
# 9  https://www.cbc.ca/news/world/protesters-michi...

# %% [markdown]
# **PART 1 - SpaCy's NER**
#
# Let's start by looking at the NER that is performed by spaCy.  SpaCy's documentation does not tell us how exactly their NER is done (certainly their trade secret), but we can at least look at the results.
#
# As we've talked about in previous notebooks, when evaluating a process or a tool, we can do quantitative or **qualitative evaluation** of results.  In this notebook, we work at a qualitative level, meaning that we are not measuring metrics such as precision/recall on a large amount of data, but rather printing results of a few examples and try to understand these results.

# %% [markdown]
# Below is the same sentence example as in the last notebook, for which we had looked at POS-tagging and other linguistic processes.  We now use this sentence to show how to access spaCy's NER type predictions for tokens in a text.

# %%
# Same example from notebook 7, recall that we loop through the iterator found in the .ents property of a parsed sentence
sentence_example = "Government guidelines in Canada recommend that people stay at least two metres away from others as part of physical distancing measures to curb the spread of COVID-19."
sentence_example_content = sp(sentence_example)
# Loop through all tokens that contain a NER type and print the token along with the corresponding NER type
for token in sentence_example_content.ents:
    print("\"" + token.text + "\" is a " + token.label_ )
# Out:
# "Canada" is a GPE
# "at least two metres" is a CARDINAL
# "COVID-19" is a ORG

# %% [markdown]
# **(TO DO) Q1 - 5 marks**
#
# In the text of **second document** (index 1) of our corpus of documents, find out which words are *PER* (spaCy uses the *PERSON* type, rather than *PER*), *ORG* (Organization), and *GPE* (Geopolitical Entity). You must do the following for this question:
# a) (2 marks) Print each element in the text tagged as *PER*, *ORG*, and *GPE* along with its NER type from spaCy.
# b) (1 mark) Is the majority of outputs correct? Provide two examples of incorrect outputs from (a).
# c) (2 marks) Do any of the problems with the NER type predictions come from an earlier step in the NLP pipeline that is performed by spaCy? Describe the problem for two examples of your output from (a).

# %%
# ANSWER Q1(a) - 2 marks
# Select the second document (index 1)
doc = df["text"][1]
# Print each PER, ORG, GPE along with its type
doc_content = sp(doc)
for token in doc_content.ents:
    if(token.label_ == 'PERSON' or token.label_ == 'ORG' or token.label_ == 'GPE'):
        print("\"" + token.text + "\" is a " + token.label_ )
# Out:
# "COVID-19" is a PERSON
# "the World Health Organization" is a ORG
# "WHO" is a ORG
# "the Public Health Agency" is a ORG
# "Canada" is a GPE
# "W.F. Wells" is a PERSON
# "the Harvard School of Public Health" is a ORG
# "Wells" is a ORG
# "Canada" is a GPE
# "Lydia Bourouiba" is a PERSON
# "the Fluid Dynamics of Disease Transmission Laboratory" is a ORG
# "the Massachusetts Institute of Technology" is a ORG
# "Bourouiba" is a PERSON
# "Mark Loeb" is a PERSON
# "McMaster University" is a ORG
# "RNA" is a ORG
# "Wuhan" is a GPE
# "China" is a GPE
# "Nebraska" is a GPE
# "Canada" is a GPE
# "COVID-19" is a ORG
# "Gary Moore/CBC" is a PERSON
# "Allison McGeer" is a PERSON
# "Sinai Health" is a ORG
# "Toronto" is a GPE
# "COVID-19" is a PERSON
# "McGeer" is a ORG
# "McGeer" is a ORG
# "Bourouiba" is a PERSON
# "Bourouiba" is a PERSON
# "Credit Lydia Bourouiba/MIT/JAMA Networks" is a ORG
# "Samira Mubareka" is a PERSON
# "Toronto" is a GPE
# "Bourouiba" is a PERSON
# "COVID-19" is a ORG
# "McMaster" is a PERSON
# "N95" is a ORG
# "U.S." is a GPE
# "Justin Trudeau" is a PERSON
# "Mubareka" is a PERSON
# "the New England Journal of Medicine" is a ORG
# "the U.S. National Institutes of Health" is a ORG
# "U.S. National Institutes of Health" is a ORG
# "COVID-19?" is a ORG
# "Journal of the Royal Society Interface" is a ORG
# "U.S." is a GPE
# "Singapore" is a GPE
# "N95" is a ORG
# "Gary S. Settles" is a PERSON
# "Penn State University/Journal of the Royal Society Interface" is a ORG
# "The World Health Organization" is a ORG
# "Los Angeles" is a GPE
# "Italy" is a GPE
# "Austria" is a GPE

# %% [markdown]
# **ANSWER Q1 (b) - 1 mark**
# "COVID-19" is a PERSON
# "Wells" is a ORG since "W.F. Wells" is a PERSON

# %% [markdown]
# **ANSWER Q1 (c) - 2 marks**
# With NLP pipeline, COVID-19 was predict as NOUN and have nsubj dependency. And Wells was predict as PROPN and have dependency as appos. Which means it is determine correctly in NLP pipeline. This problem may be cause by it has not put COVID-19 into the word data base. And did not connect Wells to W.F. Wells.

# %% [markdown]
# **PART 2 - Text Coherence and coreference chains**
#
# As you saw in Q1, the results of spaCy are quite good, but not perfect.  One main issue with NER (not just in spaCy but in many tools) is that the annotation is performed one entity at a time without consideration of the overall document.
#
# But when looking a the whole document, and knowing that text is usually coherent, we can do some post-processing to spaCy's NER module and correct some mistakes.  By text being coherent, we mean, for example, that if a person is referred to with a particular name, e.g. *McGeer*, chances are that each time we see *McGeer* in the document, it is the same person.  All the mentions of *McGeer* form a coreference chain all refering to a single entity. So it is unlikely that *McGeer* would be once a person and once an organization.  This is not always true, there are numerous counter-examples, but it is a common assumption.  This idea is even the topic of an older much-cited NLP article called "One sense per discourse" (Gale and al. 1992).
#
# With this idea of "one sense per discourse", we will explore two different strategies to use text coherence to post-process the output from the spaCy NER module.
#
# The first strategy (*explored in Q2/Q3*) is to find, among all NER types assigned, which is the most frequent one.  For example, the name *Bourouiba* was assigned 1 time ORG, and 2 times PERSON, so this information can be used to modify the ORG type and change it to PERSON.
#
# The second strategy (explored in Q4) is to try to find a longer surface form in the text.  Since that longer form should be less ambiguous, we can use it to disambiguate the shorter, more ambiguous forms.  For example, *Lydia Bourouiba* occurs in the text and is assigned PERSON.  We can use that information to assign further occurrences of the short form *Bourouiba* to also be PERSON.
#
# Of course, using these methods for text coherence will not work every time, and will unfortunately introduce some errors...  But let's try.  That's what empirical studies are about, we try ideas.

# %% [markdown]
# Let's take again the news article from Q1, but this time, let's show not only GPE, PER, ORG, but rather all the Named Entities found by spaCy.

# %%
# Select document 2
doc = df["text"][1]
# NER
doc_sp = sp(doc)
# Display all entities from the text along with their index in the .ents iterator and the
# corresponding NER type
for i, token in enumerate(doc_sp.ents):
    print(str(i) + ": \"" + token.text + "\" is a " + token.label_ )
# Out:
# 0: "weekly" is a DATE
# 1: "Saturday" is a DATE
# 2: "morning" is a TIME
# 3: "two metres" is a QUANTITY
# 4: "COVID-19" is a PERSON
# 5: "the World Health Organization" is a ORG
# 6: "WHO" is a ORG
# 7: "more than one metre" is a QUANTITY
# 8: "the Public Health Agency" is a ORG
# 9: "Canada" is a GPE
# 10: "at least two metres" is a QUANTITY
# 11: "two" is a CARDINAL
# 12: "2 metres" is a QUANTITY
# 13: "the 19th century" is a DATE
# 14: "1934" is a DATE
# 15: "W.F. Wells" is a PERSON
# 16: "the Harvard School of Public Health" is a ORG
# 17: "two metres" is a QUANTITY
# 18: "Wells" is a ORG
# 19: "56,000" is a CARDINAL
# 20: "Canada" is a GPE
# 21: "Saturday" is a DATE
# 22: "Lydia Bourouiba" is a PERSON
# 23: "the Fluid Dynamics of Disease Transmission Laboratory" is a ORG
# 24: "the Massachusetts Institute of Technology" is a ORG
# 25: "Bourouiba" is a PERSON
# 26: "Canadian" is a NORP
# 27: "Mark Loeb" is a PERSON
# 28: "McMaster University" is a ORG
# 29: "RNA" is a ORG
# 30: "Wuhan" is a GPE
# 31: "China" is a GPE
# 32: "Nebraska" is a GPE
# 33: "Canada" is a GPE
# 34: "at least two metres" is a CARDINAL
# 35: "COVID-19" is a ORG
# 36: "Gary Moore/CBC" is a PERSON
# 37: "Allison McGeer" is a PERSON
# 38: "Sinai Health" is a ORG
# 39: "Toronto" is a GPE
# 40: "COVID-19" is a PERSON
# 41: "hundreds" is a CARDINAL
# 42: "hours" is a TIME
# 43: "N-95" is a PRODUCT
# 44: "McGeer" is a ORG
# 45: "five minutes" is a TIME
# 46: "McGeer" is a ORG
# 47: "Bourouiba" is a PERSON
# 48: "Bourouiba" is a PERSON
# 49: "farther than two metres" is a QUANTITY
# 50: "seven or eight metres" is a QUANTITY
# 51: "Credit Lydia Bourouiba/MIT/JAMA Networks" is a ORG
# 52: "Canadian" is a NORP
# 53: "about one kilometre" is a QUANTITY
# 54: "two-metre" is a QUANTITY
# 55: "up to three minutes" is a TIME
# 56: "Samira Mubareka" is a PERSON
# 57: "Sunnybrook Hospital" is a FAC
# 58: "Toronto" is a GPE
# 59: "2-metre" is a QUANTITY
# 60: "Bourouiba" is a PERSON
# 61: "two metres" is a QUANTITY
# 62: "March" is a DATE
# 63: "farther than two metres" is a QUANTITY
# 64: "two metres" is a QUANTITY
# 65: "Mubareka" is a PRODUCT
# 66: "two-metre" is a QUANTITY
# 67: "Second" is a ORDINAL
# 68: "COVID-19" is a ORG
# 69: "McMaster" is a PERSON
# 70: "N95" is a ORG
# 71: "U.S." is a GPE
# 72: "Canadian" is a NORP
# 73: "Justin Trudeau" is a PERSON
# 74: "Mubareka" is a PERSON
# 75: "April 2020" is a DATE
# 76: "the New England Journal of Medicine" is a ORG
# 77: "the U.S. National Institutes of Health" is a ORG
# 78: "0:42" is a DATE
# 79: "U.S. National Institutes of Health" is a ORG
# 80: "less than 10" is a CARDINAL
# 81: "COVID-19?" is a ORG
# 82: "2009" is a DATE
# 83: "Journal of the Royal Society Interface" is a ORG
# 84: "2009" is a DATE
# 85: "U.S." is a GPE
# 86: "Singapore" is a GPE
# 87: "N95" is a ORG
# 88: "Gary S. Settles" is a PERSON
# 89: "Penn State University/Journal of the Royal Society Interface" is a ORG
# 90: "The World Health Organization" is a ORG
# 91: "Los Angeles" is a GPE
# 92: "Italy" is a GPE
# 93: "Austria" is a GPE
# 94: "Saturday" is a DATE
# 95: "morning" is a TIME

# %% [markdown]
# **(TO DO) Q2 - 3 marks**
# As you can see in the results, sometimes the same entity was assigned different entity types (e.g. *McGeer* is one time assigned entity type ORG, and one time entity type PERSON) since the NER algorithm looks sentence by sentence.  In the following function, the purpose will be to find all the possible entity types assigned to a single entity.
#
# Complete the definition of the *find_entity_types* function below. This function accepts as input a specific spaCy entity defined by the *entity* parameter and a list of all spaCy entities defined by the *entities* parameter.
#
# The function must find all entities (from *entities*) having the same surface form as *entity*. For each match between the entities, add the NER type to the dictionary *type_counts* and track the number of times each NER type appears.
#
# The *type_counts* dictionary would contain for example *McGeer* with ORG = 1, and PERSON = 1, because the function found 2 mentions of *McGeer*, each with a different type.

# %%
# ANSWER Q2 
def find_entity_types(entity, entities):
    '''
    Given a specific entity and a list of entities, finds all entities from the list that match surface form of the specified
    entity, but that could be of a different type.
    
    Returns the different NER types that have been classified for an entity and the count per NER type
    as a dictionary with the keys as the NER type and the value as the count
    '''
    type_counts = { }
    add_list=[]
    add_list_label=[]
    for token in entities:
        if (str(entity) in str(token)) or (str(token) in str(entity)):
            if(str(token) not in add_list) or (str(token.label_) not in add_list_label):
                if(token.label_ not in type_counts):
                    type_counts[token.label_] = 1
                    add_list.append(str(token))
                    add_list_label.append(str(token.label_))
                else:
                    type_counts[token.label_] += 1
                    add_list.append(str(token))
                    add_list_label.append(str(token.label_))
    return type_counts

# %%
# Test the above to find the result when checking for the types of the entity 'Bourouiba' 
# from the document loaded above
print("All possible NER types for \"" + doc_sp.ents[47].text + "\" are " + str(find_entity_types(doc_sp.ents[47], doc_sp.ents)))
print("All possible NER types for \"" + doc_sp.ents[44].text + "\" are " + str(find_entity_types(doc_sp.ents[44], doc_sp.ents)))
print("All possible NER types for \"" + doc_sp.ents[4].text + "\" are " + str(find_entity_types(doc_sp.ents[4], doc_sp.ents)))
# Out:
# All possible NER types for "Bourouiba" are {'PERSON': 2, 'ORG': 1}
# All possible NER types for "McGeer" are {'PERSON': 1, 'ORG': 1}
# All possible NER types for "COVID-19" are {'PERSON': 1, 'ORG': 2}

# %% [markdown]
# **(TO DO) Q3 - 2 marks**
# In the previous method, *find_entity_types*, we found all the possible entity types for a single entity.  Now, we want to use these to find the most common type.  For example, in the case of *McGeer*, it's a tie.  But for *Bourouiba*, there is one ORG type, and 2 PERSON type, so the most common would be PERSON.
#
# Complete the definition of the *most_common_type* function below. This function accepts as input a specific spaCy entity defined by the *entity* parameter and a list of all spaCy entities defined by the *entities* parameter.
#
# Note: You can handle ties as you please.  Also, make sure to use the function *find_entity_types* which you just wrote in Q2.

# %%
# ANSWER Q3 
def most_common_type(entity, entities):
    '''
    Given a specific entity and a list of entities, find the most similar entities and assign the
    NER type to entity based on the most common NER type assigned to entities of the same name (if there
    is a tie, you decide how to handle this).
    
    Returns the most common NER type based on similar entities
    '''
    # TODO
    type_counts = find_entity_types(entity, entities)
    max_value = 0
    for key in type_counts:
        if type_counts[key] > max_value:
            max_value = type_counts[key]
    for key in type_counts:
        if type_counts[key] == max_value:
            return key

# %%
# Test the above to find the result when checking for the types of the entity 'Bourouiba' 
# from the document loaded above
print("The most common NER type to \"" + doc_sp.ents[47].text + "\" is " + most_common_type(doc_sp.ents[47], doc_sp.ents))
# Out:
# The most common NER type to "Bourouiba" is PERSON

# %% [markdown]
# Our first exploration (in Q2/Q3) was about frequency of occurrence.  We assumed the most common entity type could be the correct one.  Now, we'll explore the idea that the least ambiguous reference to an entity (the actual text) could be the correct one.  For example, *McGeer* is more ambiguous (shorter form) than *Allison McGeer* (longer form).  Often the longer form of reference to an entity is the least ambiguous.  But because it is long to write, we often use it sparingly in a text (perhaps only once) and then subsequent references to the same entity will use the shorter form.  For example, the text might mention *Allison McGeer* once, and then use the short form *McGeer* to refer to the same person many times in the document.
#
# In the course videos, we talked about the coreference chains. Thus, a chain contains long and short mentions, all referring to the same entity.
#
# The longer form is often referred to as the *normalized form*, and it is a form that we are likely to find in an external resource.  We'll see in part 3 of this notebook, when we do entity linking, that there is a Wikipedia entry for *Allison McGeer* that we could link to. We can consider the longer *Allison McGeer* form as the normalized form.

# %% [markdown]
# **(TO DO) Q4 (a) - 3 marks**
#
# You must write a function that will find the longest form that can match a mention.
#
# Your function will have the same *entity* and *entities* parameters, but this time the function must assign to *entity* the NER type of another entity in the *entities* iterator, that of the longest form found.
#
# Specifically, you must look through *entities* to find a normalized form of *entity*. In this scenario, the longest entity that contains *entity* as a substring will be considered the normalized form and should be returned.  If no longer form is found, the entity itself *entity* should be returned.
#
# Ex: *Lydia Bourouiba* is the normalized form of *Bourouiba*. Thus this entity should be returned.  But *McMaster University* is already the longest form, so if we search for a normalized form for that *entity*, the function should return *entity* itself.

# %%
# ANSWER Q4(a)
# Find the longest surface form within "entities" for which the surface for of "entity" is a substring
def assign_normalized_form(entity, entities):
    max_word = entity
    max_length = 0
    for word in entities:
        #max_word = word
        #max_length = 0
        if str(entity) in str(word) and str(entity.label_) == str(word.label_):
            if len(str(word)) > max_length:
                max_length = len(str(word))
                max_word = word
            else:
                max_word = max_word
                max_length = max_length
    return max_word

# %% [markdown]
# Let's test the above function, assuming the candidates are only found in the previous mentions, as often a long form is given first to (e.g. *Allison McGeer*) and subsequent forms are the short forms (e.g. *McGeer*).

# %%
# Testing using only the previous references as candidates
test = df["text"][1]
# Parse the text with spaCy
test_sp = sp(test)
for i, token in enumerate(test_sp.ents):
    ent = assign_normalized_form(test_sp.ents[i], test_sp.ents[0:i-1])
    print(str(i) + ": \"" + token.text + "\" is a " + token.label_ + "  " + ent.text + "  " + ent.label_)
# Out:
# 0: "weekly" is a DATE  weekly  DATE
# 1: "Saturday" is a DATE  Saturday  DATE
# 2: "morning" is a TIME  morning  TIME
# 3: "two metres" is a QUANTITY  two metres  QUANTITY
# 4: "COVID-19" is a PERSON  COVID-19  PERSON
# 5: "the World Health Organization" is a ORG  the World Health Organization  ORG
# 6: "WHO" is a ORG  WHO  ORG
# 7: "more than one metre" is a QUANTITY  more than one metre  QUANTITY
# 8: "the Public Health Agency" is a ORG  the Public Health Agency  ORG
# 9: "Canada" is a GPE  Canada  GPE
# 10: "at least two metres" is a QUANTITY  at least two metres  QUANTITY
# 11: "two" is a CARDINAL  two  CARDINAL
# 12: "2 metres" is a QUANTITY  2 metres  QUANTITY
# 13: "the 19th century" is a DATE  the 19th century  DATE
# 14: "1934" is a DATE  1934  DATE
# 15: "W.F. Wells" is a PERSON  W.F. Wells  PERSON
# 16: "the Harvard School of Public Health" is a ORG  the Harvard School of Public Health  ORG
# 17: "two metres" is a QUANTITY  at least two metres  QUANTITY
# 18: "Wells" is a ORG  Wells  ORG
# 19: "56,000" is a CARDINAL  56,000  CARDINAL
# 20: "Canada" is a GPE  Canada  GPE
# 21: "Saturday" is a DATE  Saturday  DATE
# 22: "Lydia Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 23: "the Fluid Dynamics of Disease Transmission Laboratory" is a ORG  the Fluid Dynamics of Disease Transmission Laboratory  ORG
# 24: "the Massachusetts Institute of Technology" is a ORG  the Massachusetts Institute of Technology  ORG
# 25: "Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 26: "Canadian" is a NORP  Canadian  NORP
# 27: "Mark Loeb" is a PERSON  Mark Loeb  PERSON
# 28: "McMaster University" is a ORG  McMaster University  ORG
# 29: "RNA" is a ORG  RNA  ORG
# 30: "Wuhan" is a GPE  Wuhan  GPE
# 31: "China" is a GPE  China  GPE
# 32: "Nebraska" is a GPE  Nebraska  GPE
# 33: "Canada" is a GPE  Canada  GPE
# 34: "at least two metres" is a CARDINAL  at least two metres  CARDINAL
# 35: "COVID-19" is a ORG  COVID-19  ORG
# 36: "Gary Moore/CBC" is a PERSON  Gary Moore/CBC  PERSON
# 37: "Allison McGeer" is a PERSON  Allison McGeer  PERSON
# 38: "Sinai Health" is a ORG  Sinai Health  ORG
# 39: "Toronto" is a GPE  Toronto  GPE
# 40: "COVID-19" is a PERSON  COVID-19  PERSON
# 41: "hundreds" is a CARDINAL  hundreds  CARDINAL
# 42: "hours" is a TIME  hours  TIME
# 43: "N-95" is a PRODUCT  N-95  PRODUCT
# 44: "McGeer" is a ORG  McGeer  ORG
# 45: "five minutes" is a TIME  five minutes  TIME
# 46: "McGeer" is a ORG  McGeer  ORG
# 47: "Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 48: "Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 49: "farther than two metres" is a QUANTITY  farther than two metres  QUANTITY
# 50: "seven or eight metres" is a QUANTITY  seven or eight metres  QUANTITY
# 51: "Credit Lydia Bourouiba/MIT/JAMA Networks" is a ORG  Credit Lydia Bourouiba/MIT/JAMA Networks  ORG
# 52: "Canadian" is a NORP  Canadian  NORP
# 53: "about one kilometre" is a QUANTITY  about one kilometre  QUANTITY
# 54: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 55: "up to three minutes" is a TIME  up to three minutes  TIME
# 56: "Samira Mubareka" is a PERSON  Samira Mubareka  PERSON
# 57: "Sunnybrook Hospital" is a FAC  Sunnybrook Hospital  FAC
# 58: "Toronto" is a GPE  Toronto  GPE
# 59: "2-metre" is a QUANTITY  2-metre  QUANTITY
# 60: "Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 61: "two metres" is a QUANTITY  farther than two metres  QUANTITY
# 62: "March" is a DATE  March  DATE
# 63: "farther than two metres" is a QUANTITY  farther than two metres  QUANTITY
# 64: "two metres" is a QUANTITY  farther than two metres  QUANTITY
# 65: "Mubareka" is a PRODUCT  Mubareka  PRODUCT
# 66: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 67: "Second" is a ORDINAL  Second  ORDINAL
# 68: "COVID-19" is a ORG  COVID-19  ORG
# 69: "McMaster" is a PERSON  McMaster  PERSON
# 70: "N95" is a ORG  N95  ORG
# 71: "U.S." is a GPE  U.S.  GPE
# 72: "Canadian" is a NORP  Canadian  NORP
# 73: "Justin Trudeau" is a PERSON  Justin Trudeau  PERSON
# 74: "Mubareka" is a PERSON  Samira Mubareka  PERSON
# 75: "April 2020" is a DATE  April 2020  DATE
# 76: "the New England Journal of Medicine" is a ORG  the New England Journal of Medicine  ORG
# 77: "the U.S. National Institutes of Health" is a ORG  the U.S. National Institutes of Health  ORG
# 78: "0:42" is a DATE  0:42  DATE
# 79: "U.S. National Institutes of Health" is a ORG  the U.S. National Institutes of Health  ORG
# 80: "less than 10" is a CARDINAL  less than 10  CARDINAL
# 81: "COVID-19?" is a ORG  COVID-19?  ORG
# 82: "2009" is a DATE  2009  DATE
# 83: "Journal of the Royal Society Interface" is a ORG  Journal of the Royal Society Interface  ORG
# 84: "2009" is a DATE  2009  DATE
# 85: "U.S." is a GPE  U.S.  GPE
# 86: "Singapore" is a GPE  Singapore  GPE
# 87: "N95" is a ORG  N95  ORG
# 88: "Gary S. Settles" is a PERSON  Gary S. Settles  PERSON
# 89: "Penn State University/Journal of the Royal Society Interface" is a ORG  Penn State University/Journal of the Royal Society Interface  ORG
# 90: "The World Health Organization" is a ORG  The World Health Organization  ORG
# 91: "Los Angeles" is a GPE  Los Angeles  GPE
# 92: "Italy" is a GPE  Italy  GPE
# 93: "Austria" is a GPE  Austria  GPE
# 94: "Saturday" is a DATE  Saturday  DATE
# 95: "morning" is a TIME  morning  TIME

# %% [markdown]
# **(TO DO) Q4 (b) - 2 marks**
#
# Do other tests without the limitation of using only longer forms mentioned before an entity (see *test_sp.ents[0:i-1]* in the code above), try searching before and after.  Or try an interval (e.g. max N entities before or after).  Explain what you tested.  Any difference?  Provide at least 2 examples of changes that you notice.

# %%
# ANSWER Q4(b)
# Do a different test
test = df["text"][1]
# Parse the text with spaCy
test_sp = sp(test)
for i, token in enumerate(test_sp.ents):
    ent = assign_normalized_form(test_sp.ents[i], test_sp.ents[0:10])
    print(str(i) + ": \"" + token.text + "\" is a " + token.label_ + "  " + ent.text + "  " + ent.label_)
# Out:
# 0: "weekly" is a DATE  weekly  DATE
# 1: "Saturday" is a DATE  Saturday  DATE
# 2: "morning" is a TIME  morning  TIME
# 3: "two metres" is a QUANTITY  two metres  QUANTITY
# 4: "COVID-19" is a PERSON  COVID-19  PERSON
# 5: "the World Health Organization" is a ORG  the World Health Organization  ORG
# 6: "WHO" is a ORG  WHO  ORG
# 7: "more than one metre" is a QUANTITY  more than one metre  QUANTITY
# 8: "the Public Health Agency" is a ORG  the Public Health Agency  ORG
# 9: "Canada" is a GPE  Canada  GPE
# 10: "at least two metres" is a QUANTITY  at least two metres  QUANTITY
# 11: "two" is a CARDINAL  two metres  QUANTITY
# 12: "2 metres" is a QUANTITY  2 metres  QUANTITY
# 13: "the 19th century" is a DATE  the 19th century  DATE
# 14: "1934" is a DATE  1934  DATE
# 15: "W.F. Wells" is a PERSON  W.F. Wells  PERSON
# 16: "the Harvard School of Public Health" is a ORG  the Harvard School of Public Health  ORG
# 17: "two metres" is a QUANTITY  two metres  QUANTITY
# 18: "Wells" is a ORG  Wells  ORG
# 19: "56,000" is a CARDINAL  56,000  CARDINAL
# 20: "Canada" is a GPE  Canada  GPE
# 21: "Saturday" is a DATE  Saturday  DATE
# 22: "Lydia Bourouiba" is a PERSON  Lydia Bourouiba  PERSON
# 23: "the Fluid Dynamics of Disease Transmission Laboratory" is a ORG  the Fluid Dynamics of Disease Transmission Laboratory  ORG
# 24: "the Massachusetts Institute of Technology" is a ORG  the Massachusetts Institute of Technology  ORG
# 25: "Bourouiba" is a PERSON  Bourouiba  PERSON
# 26: "Canadian" is a NORP  Canadian  NORP
# 27: "Mark Loeb" is a PERSON  Mark Loeb  PERSON
# 28: "McMaster University" is a ORG  McMaster University  ORG
# 29: "RNA" is a ORG  RNA  ORG
# 30: "Wuhan" is a GPE  Wuhan  GPE
# 31: "China" is a GPE  China  GPE
# 32: "Nebraska" is a GPE  Nebraska  GPE
# 33: "Canada" is a GPE  Canada  GPE
# 34: "at least two metres" is a CARDINAL  at least two metres  CARDINAL
# 35: "COVID-19" is a ORG  COVID-19  PERSON
# 36: "Gary Moore/CBC" is a PERSON  Gary Moore/CBC  PERSON
# 37: "Allison McGeer" is a PERSON  Allison McGeer  PERSON
# 38: "Sinai Health" is a ORG  Sinai Health  ORG
# 39: "Toronto" is a GPE  Toronto  GPE
# 40: "COVID-19" is a PERSON  COVID-19  PERSON
# 41: "hundreds" is a CARDINAL  hundreds  CARDINAL
# 42: "hours" is a TIME  hours  TIME
# 43: "N-95" is a PRODUCT  N-95  PRODUCT
# 44: "McGeer" is a ORG  McGeer  ORG
# 45: "five minutes" is a TIME  five minutes  TIME
# 46: "McGeer" is a ORG  McGeer  ORG
# 47: "Bourouiba" is a PERSON  Bourouiba  PERSON
# 48: "Bourouiba" is a PERSON  Bourouiba  PERSON
# 49: "farther than two metres" is a QUANTITY  farther than two metres  QUANTITY
# 50: "seven or eight metres" is a QUANTITY  seven or eight metres  QUANTITY
# 51: "Credit Lydia Bourouiba/MIT/JAMA Networks" is a ORG  Credit Lydia Bourouiba/MIT/JAMA Networks  ORG
# 52: "Canadian" is a NORP  Canadian  NORP
# 53: "about one kilometre" is a QUANTITY  about one kilometre  QUANTITY
# 54: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 55: "up to three minutes" is a TIME  up to three minutes  TIME
# 56: "Samira Mubareka" is a PERSON  Samira Mubareka  PERSON
# 57: "Sunnybrook Hospital" is a FAC  Sunnybrook Hospital  FAC
# 58: "Toronto" is a GPE  Toronto  GPE
# 59: "2-metre" is a QUANTITY  2-metre  QUANTITY
# 60: "Bourouiba" is a PERSON  Bourouiba  PERSON
# 61: "two metres" is a QUANTITY  two metres  QUANTITY
# 62: "March" is a DATE  March  DATE
# 63: "farther than two metres" is a QUANTITY  farther than two metres  QUANTITY
# 64: "two metres" is a QUANTITY  two metres  QUANTITY
# 65: "Mubareka" is a PRODUCT  Mubareka  PRODUCT
# 66: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 67: "Second" is a ORDINAL  Second  ORDINAL
# 68: "COVID-19" is a ORG  COVID-19  PERSON
# 69: "McMaster" is a PERSON  McMaster  PERSON
# 70: "N95" is a ORG  N95  ORG
# 71: "U.S." is a GPE  U.S.  GPE
# 72: "Canadian" is a NORP  Canadian  NORP
# 73: "Justin Trudeau" is a PERSON  Justin Trudeau  PERSON
# 74: "Mubareka" is a PERSON  Mubareka  PERSON
# 75: "April 2020" is a DATE  April 2020  DATE
# 76: "the New England Journal of Medicine" is a ORG  the New England Journal of Medicine  ORG
# 77: "the U.S. National Institutes of Health" is a ORG  the U.S. National Institutes of Health  ORG
# 78: "0:42" is a DATE  0:42  DATE
# 79: "U.S. National Institutes of Health" is a ORG  U.S. National Institutes of Health  ORG
# 80: "less than 10" is a CARDINAL  less than 10  CARDINAL
# 81: "COVID-19?" is a ORG  COVID-19?  ORG
# 82: "2009" is a DATE  2009  DATE
# 83: "Journal of the Royal Society Interface" is a ORG  Journal of the Royal Society Interface  ORG
# 84: "2009" is a DATE  2009  DATE
# 85: "U.S." is a GPE  U.S.  GPE
# 86: "Singapore" is a GPE  Singapore  GPE
# 87: "N95" is a ORG  N95  ORG
# 88: "Gary S. Settles" is a PERSON  Gary S. Settles  PERSON
# 89: "Penn State University/Journal of the Royal Society Interface" is a ORG  Penn State University/Journal of the Royal Society Interface  ORG
# 90: "The World Health Organization" is a ORG  The World Health Organization  ORG
# 91: "Los Angeles" is a GPE  Los Angeles  GPE
# 92: "Italy" is a GPE  Italy  GPE
# 93: "Austria" is a GPE  Austria  GPE
# 94: "Saturday" is a DATE  Saturday  DATE
# 95: "morning" is a TIME  morning  TIME

# %% [markdown]
# **ANSWER Q4(b)**
#
# I test 10 entites after. The accuracy become lower, such as Bourouiba can not be connect to Lydia Bourouiba, and McGeer also can not be connect to Allison McGeer.

# %% [markdown]
# **(TO DO) Q5 - 5 marks**
# Use a different news article in the corpus, the 7th article, so index 6.
#
# (a) (2 marks) Run the two approaches (most frequent, longest form).  For each entity found in the text, print its original entity type (as found by spaCy, then the most common entity type, and then the normalized form with its entity type. \
# (b) (3 marks) Analyze and discuss the results.  Do you think these text coherence approaches help or are they too simple?  Are there conflicting results (the two approaches give different results).  If yes, show examples that are different.

# %%
# ANSWER Q5(a) 
# Select document index 6
doc = df["text"][6]
doc_sp = sp(doc)
# Display all entities from the text along with their index in the .ents iterator and the
# corresponding NER type
for i, token in enumerate(doc_sp.ents):
    print(str(i) + ": \"" + token.text + "\" is a " + token.label_ )
    print("The most common NER type to \"" + doc_sp.ents[i].text + "\" is " + most_common_type(doc_sp.ents[i], doc_sp.ents))
    ent = assign_normalized_form(doc_sp.ents[i], doc_sp.ents[0:i-1])
    print(str(i) + ": \"" + token.text + "\" is a " + token.label_ + "  " + ent.text + "  " + ent.label_)
# Out:
# 0: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 0: "Canada" is a GPE  Canada  GPE
# 1: "C.D. Howe" is a ORG
# The most common NER type to "C.D. Howe" is ORG
# 1: "C.D. Howe" is a ORG  C.D. Howe  ORG
# 2: "Ontario" is a PERSON
# The most common NER type to "Ontario" is PERSON
# 2: "Ontario" is a PERSON  Ontario  PERSON
# 3: "Monday" is a DATE
# The most common NER type to "Monday" is DATE
# 3: "Monday" is a DATE  Monday  DATE
# 4: "Alberta" is a GPE
# The most common NER type to "Alberta" is GPE
# 4: "Alberta" is a GPE  Alberta  GPE
# 5: "first" is a ORDINAL
# The most common NER type to "first" is ORDINAL
# 5: "first" is a ORDINAL  first  ORDINAL
# 6: "Saturday" is a DATE
# The most common NER type to "Saturday" is DATE
# 6: "Saturday" is a DATE  Saturday  DATE
# 7: "Air Canada" is a ORG
# The most common NER type to "Air Canada" is GPE
# 7: "Air Canada" is a ORG  Air Canada  ORG
# 8: "Christmas" is a DATE
# The most common NER type to "Christmas" is DATE
# 8: "Christmas" is a DATE  Christmas  DATE
# 9: "more than $1.2 million" is a MONEY
# The most common NER type to "more than $1.2 million" is MONEY
# 9: "more than $1.2 million" is a MONEY  more than $1.2 million  MONEY
# 10: "England" is a GPE
# The most common NER type to "England" is GPE
# 10: "England" is a GPE  England  GPE
# 11: "Peter Cziborra/Reuters" is a PERSON
# The most common NER type to "Peter Cziborra/Reuters" is PERSON
# 11: "Peter Cziborra/Reuters" is a PERSON  Peter Cziborra/Reuters  PERSON
# 12: "months" is a DATE
# The most common NER type to "months" is DATE
# 12: "months" is a DATE  months  DATE
# 13: "CBC" is a ORG
# The most common NER type to "CBC" is ORG
# 13: "CBC" is a ORG  CBC  ORG
# 14: "Andre Mayer" is a PERSON
# The most common NER type to "Andre Mayer" is PERSON
# 14: "Andre Mayer" is a PERSON  Andre Mayer  PERSON
# 15: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 15: "Canada" is a GPE  Air Canada  ORG
# 16: "19th-century" is a DATE
# The most common NER type to "19th-century" is DATE
# 16: "19th-century" is a DATE  19th-century  DATE
# 17: "cholera" is a ORG
# The most common NER type to "cholera" is ORG
# 17: "cholera" is a ORG  cholera  ORG
# 18: "2013" is a DATE
# The most common NER type to "2013" is DATE
# 18: "2013" is a DATE  2013  DATE
# 19: "Calgary" is a GPE
# The most common NER type to "Calgary" is GPE
# 19: "Calgary" is a GPE  Calgary  GPE
# 20: "John Brown" is a PERSON
# The most common NER type to "John Brown" is PERSON
# 20: "John Brown" is a PERSON  John Brown  PERSON
# 21: "the University of Calgary" is a ORG
# The most common NER type to "the University of Calgary" is GPE
# 21: "the University of Calgary" is a ORG  the University of Calgary  ORG
# 22: "two-metre" is a QUANTITY
# The most common NER type to "two-metre" is QUANTITY
# 22: "two-metre" is a QUANTITY  two-metre  QUANTITY
# 23: "Last week" is a DATE
# The most common NER type to "Last week" is DATE
# 23: "Last week" is a DATE  Last week  DATE
# 24: "Italian" is a NORP
# The most common NER type to "Italian" is NORP
# 24: "Italian" is a NORP  Italian  NORP
# 25: "Milan" is a GPE
# The most common NER type to "Milan" is GPE
# 25: "Milan" is a GPE  Milan  GPE
# 26: "35 kilometres" is a QUANTITY
# The most common NER type to "35 kilometres" is QUANTITY
# 26: "35 kilometres" is a QUANTITY  35 kilometres  QUANTITY
# 27: "Berlin" is a GPE
# The most common NER type to "Berlin" is GPE
# 27: "Berlin" is a GPE  Berlin  GPE
# 28: "Budapest" is a GPE
# The most common NER type to "Budapest" is GPE
# 28: "Budapest" is a GPE  Budapest  GPE
# 29: "Mexico City" is a GPE
# The most common NER type to "Mexico City" is GPE
# 29: "Mexico City" is a GPE  Mexico City  GPE
# 30: "Ahsan Habib" is a PERSON
# The most common NER type to "Ahsan Habib" is PERSON
# 30: "Ahsan Habib" is a PERSON  Ahsan Habib  PERSON
# 31: "Dalhousie University" is a ORG
# The most common NER type to "Dalhousie University" is ORG
# 31: "Dalhousie University" is a ORG  Dalhousie University  ORG
# 32: "U.S." is a GPE
# The most common NER type to "U.S." is GPE
# 32: "U.S." is a GPE  U.S.  GPE
# 33: "Atlanta" is a GPE
# The most common NER type to "Atlanta" is GPE
# 33: "Atlanta" is a GPE  Atlanta  GPE
# 34: "Chicago" is a GPE
# The most common NER type to "Chicago" is GPE
# 34: "Chicago" is a GPE  Chicago  GPE
# 35: "Denver" is a GPE
# The most common NER type to "Denver" is GPE
# 35: "Denver" is a GPE  Denver  GPE
# 36: "Habib" is a PERSON
# The most common NER type to "Habib" is PERSON
# 36: "Habib" is a PERSON  Ahsan Habib  PERSON
# 37: "Brown" is a PERSON
# The most common NER type to "Brown" is PERSON
# 37: "Brown" is a PERSON  John Brown  PERSON
# 38: "Calgary" is a GPE
# The most common NER type to "Calgary" is GPE
# 38: "Calgary" is a GPE  the University of Calgary  ORG
# 39: "Housebrand" is a ORG
# The most common NER type to "Housebrand" is ORG
# 39: "Housebrand" is a ORG  Housebrand  ORG
# 40: "The National The At" is a WORK_OF_ART
# The most common NER type to "The National The At" is WORK_OF_ART
# 40: "The National The At" is a WORK_OF_ART  The National The At  WORK_OF_ART
# 41: "Quebec" is a GPE
# The most common NER type to "Quebec" is GPE
# 41: "Quebec" is a GPE  Quebec  GPE
# 42: "Conservative" is a NORP
# The most common NER type to "Conservative" is NORP
# 42: "Conservative" is a NORP  Conservative  NORP
# 43: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 43: "Canada" is a GPE  Canada  GPE
# 44: "C.D. Howe" is a ORG
# The most common NER type to "C.D. Howe" is ORG
# 44: "C.D. Howe" is a ORG  C.D. Howe  ORG
# 45: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 45: "Canada" is a GPE  Canada  GPE
# 46: "the C.D. Howe Institute's" is a ORG
# The most common NER type to "the C.D. Howe Institute's" is ORG
# 46: "the C.D. Howe Institute's" is a ORG  the C.D. Howe Institute's  ORG
# 47: "Business Cycle Council" is a ORG
# The most common NER type to "Business Cycle Council" is ORG
# 47: "Business Cycle Council" is a ORG  Business Cycle Council  ORG
# 48: "today" is a DATE
# The most common NER type to "today" is DATE
# 48: "today" is a DATE  today  DATE
# 49: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 49: "Canada" is a GPE  Canada  GPE
# 50: "February" is a DATE
# The most common NER type to "February" is DATE
# 50: "February" is a DATE  February  DATE
# 51: "one" is a CARDINAL
# The most common NER type to "one" is CARDINAL
# 51: "one" is a CARDINAL  one  CARDINAL
# 52: "two" is a CARDINAL
# The most common NER type to "two" is QUANTITY
# 52: "two" is a CARDINAL  two-metre  QUANTITY
# 53: "three-month" is a DATE
# The most common NER type to "three-month" is DATE
# 53: "three-month" is a DATE  three-month  DATE
# 54: "less than two months old" is a DATE
# The most common NER type to "less than two months old" is DATE
# 54: "less than two months old" is a DATE  less than two months old  DATE
# 55: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 55: "Canada" is a GPE  Canada  GPE
# 56: "first" is a ORDINAL
# The most common NER type to "first" is ORDINAL
# 56: "first" is a ORDINAL  first  ORDINAL
# 57: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 57: "Canada" is a GPE  Canada  GPE
# 58: "2008" is a DATE
# The most common NER type to "2008" is DATE
# 58: "2008" is a DATE  2008  DATE
# 59: "March" is a DATE
# The most common NER type to "March" is DATE
# 59: "March" is a DATE  March  DATE
# 60: "April" is a DATE
# The most common NER type to "April" is DATE
# 60: "April" is a DATE  April  DATE
# 61: "the entire month" is a DATE
# The most common NER type to "the entire month" is DATE
# 61: "the entire month" is a DATE  the entire month  DATE
# 62: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 62: "Canada" is a GPE  Canada  GPE
# 63: "Monday" is a DATE
# The most common NER type to "Monday" is DATE
# 63: "Monday" is a DATE  Monday  DATE
# 64: "Alberta" is a GPE
# The most common NER type to "Alberta" is GPE
# 64: "Alberta" is a GPE  Alberta  GPE
# 65: "Saturday" is a DATE
# The most common NER type to "Saturday" is DATE
# 65: "Saturday" is a DATE  Saturday  DATE
# 66: "today" is a DATE
# The most common NER type to "today" is DATE
# 66: "today" is a DATE  today  DATE
# 67: "Monday" is a DATE
# The most common NER type to "Monday" is DATE
# 67: "Monday" is a DATE  Monday  DATE
# 68: "Today" is a DATE
# The most common NER type to "Today" is DATE
# 68: "Today" is a DATE  Today  DATE
# 69: "Doug Ford" is a PERSON
# The most common NER type to "Doug Ford" is PERSON
# 69: "Doug Ford" is a PERSON  Doug Ford  PERSON
# 70: "Alberta" is a GPE
# The most common NER type to "Alberta" is GPE
# 70: "Alberta" is a GPE  Alberta  GPE
# 71: "Jason Kenney" is a PERSON
# The most common NER type to "Jason Kenney" is PERSON
# 71: "Jason Kenney" is a PERSON  Jason Kenney  PERSON
# 72: "first" is a ORDINAL
# The most common NER type to "first" is ORDINAL
# 72: "first" is a ORDINAL  first  ORDINAL
# 73: "Alberta" is a GPE
# The most common NER type to "Alberta" is GPE
# 73: "Alberta" is a GPE  Alberta  GPE
# 74: "Saturday" is a DATE
# The most common NER type to "Saturday" is DATE
# 74: "Saturday" is a DATE  Saturday  DATE
# 75: "mid-May." is a DATE
# The most common NER type to "mid-May." is DATE
# 75: "mid-May." is a DATE  mid-May.  DATE
# 76: "Kenney" is a ORG
# The most common NER type to "Kenney" is PERSON
# 76: "Kenney" is a ORG  Jason Kenney  PERSON
# 77: "Thursday" is a DATE
# The most common NER type to "Thursday" is DATE
# 77: "Thursday" is a DATE  Thursday  DATE
# 78: "Monday" is a DATE
# The most common NER type to "Monday" is DATE
# 78: "Monday" is a DATE  Monday  DATE
# 79: "the academic year" is a DATE
# The most common NER type to "the academic year" is DATE
# 79: "the academic year" is a DATE  the academic year  DATE
# 80: "Kenney" is a ORG
# The most common NER type to "Kenney" is PERSON
# 80: "Kenney" is a ORG  Kenney  ORG
# 81: "summer" is a DATE
# The most common NER type to "summer" is DATE
# 81: "summer" is a DATE  summer  DATE
# 82: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 82: "Canada" is a GPE  Canada  GPE
# 83: "Christmas" is a DATE
# The most common NER type to "Christmas" is DATE
# 83: "Christmas" is a DATE  Christmas  DATE
# 84: "Air Canada" is a ORG
# The most common NER type to "Air Canada" is GPE
# 84: "Air Canada" is a ORG  Air Canada  ORG
# 85: "Canadians" is a NORP
# The most common NER type to "Canadians" is NORP
# 85: "Canadians" is a NORP  Canadians  NORP
# 86: "Tim Strauss" is a PERSON
# The most common NER type to "Tim Strauss" is PERSON
# 86: "Tim Strauss" is a PERSON  Tim Strauss  PERSON
# 87: "Canadian" is a NORP
# The most common NER type to "Canadian" is NORP
# 87: "Canadian" is a NORP  Canadians  NORP
# 88: "Air Canada" is a ORG
# The most common NER type to "Air Canada" is GPE
# 88: "Air Canada" is a ORG  Air Canada  ORG
# 89: "more than" is a CARDINAL
# The most common NER type to "more than" is CARDINAL
# 89: "more than" is a CARDINAL  more than $1.2 million  MONEY
# 90: "Canadian Club Toronto" is a ORG
# The most common NER type to "Canadian Club Toronto" is NORP
# 90: "Canadian Club Toronto" is a ORG  Canadian Club Toronto  ORG
# 91: "today" is a DATE
# The most common NER type to "today" is DATE
# 91: "today" is a DATE  today  DATE
# 92: "North American" is a NORP
# The most common NER type to "North American" is NORP
# 92: "North American" is a NORP  North American  NORP
# 93: "Air Canada" is a ORG
# The most common NER type to "Air Canada" is GPE
# 93: "Air Canada" is a ORG  Air Canada  ORG
# 94: "Sunwing and American Airlines" is a ORG
# The most common NER type to "Sunwing and American Airlines" is ORG
# 94: "Sunwing and American Airlines" is a ORG  Sunwing and American Airlines  ORG
# 95: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 95: "Canada" is a GPE  Air Canada  ORG
# 96: "two metres" is a QUANTITY
# The most common NER type to "two metres" is CARDINAL
# 96: "two metres" is a QUANTITY  two metres  QUANTITY
# 97: "Air Canada" is a ORG
# The most common NER type to "Air Canada" is GPE
# 97: "Air Canada" is a ORG  Air Canada  ORG
# 98: "Christmas" is a DATE
# The most common NER type to "Christmas" is DATE
# 98: "Christmas" is a DATE  Christmas  DATE
# 99: "Helane Becker" is a PERSON
# The most common NER type to "Helane Becker" is PERSON
# 99: "Helane Becker" is a PERSON  Helane Becker  PERSON
# 100: "first" is a ORDINAL
# The most common NER type to "first" is ORDINAL
# 100: "first" is a ORDINAL  first  ORDINAL
# 101: "Becker" is a PERSON
# The most common NER type to "Becker" is PERSON
# 101: "Becker" is a PERSON  Helane Becker  PERSON
# 102: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 102: "Canada" is a GPE  Air Canada  ORG
# 103: "CBC News" is a ORG
# The most common NER type to "CBC News" is ORG
# 103: "CBC News" is a ORG  CBC News  ORG
# 104: "U.S." is a GPE
# The most common NER type to "U.S." is GPE
# 104: "U.S." is a GPE  U.S.  GPE
# 105: "U.S." is a GPE
# The most common NER type to "U.S." is GPE
# 105: "U.S." is a GPE  U.S.  GPE
# 106: "Anthony Fauci" is a PERSON
# The most common NER type to "Anthony Fauci" is PERSON
# 106: "Anthony Fauci" is a PERSON  Anthony Fauci  PERSON
# 107: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 107: "Canada" is a GPE  Canada  GPE
# 108: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 108: "Canada" is a GPE  Canada  GPE
# 109: "Health Canada" is a ORG
# The most common NER type to "Health Canada" is GPE
# 109: "Health Canada" is a ORG  Health Canada  ORG
# 110: "Gilead" is a ORG
# The most common NER type to "Gilead" is ORG
# 110: "Gilead" is a ORG  Gilead  ORG
# 111: "CBC News" is a ORG
# The most common NER type to "CBC News" is ORG
# 111: "CBC News" is a ORG  CBC News  ORG
# 112: "Gilead" is a ORG
# The most common NER type to "Gilead" is ORG
# 112: "Gilead" is a ORG  Gilead  ORG
# 113: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 113: "Canada" is a GPE  Health Canada  ORG
# 114: "Alberta" is a GPE
# The most common NER type to "Alberta" is GPE
# 114: "Alberta" is a GPE  Alberta  GPE
# 115: "daily" is a DATE
# The most common NER type to "daily" is DATE
# 115: "daily" is a DATE  daily  DATE
# 116: "Grace Horsfall Couldwell" is a PERSON
# The most common NER type to "Grace Horsfall Couldwell" is PERSON
# 116: "Grace Horsfall Couldwell" is a PERSON  Grace Horsfall Couldwell  PERSON
# 117: "daily" is a DATE
# The most common NER type to "daily" is DATE
# 117: "daily" is a DATE  daily  DATE
# 118: "Alberta" is a GPE
# The most common NER type to "Alberta" is GPE
# 118: "Alberta" is a GPE  Alberta  GPE
# 119: "MJ Stead" is a PERSON
# The most common NER type to "MJ Stead" is PERSON
# 119: "MJ Stead" is a PERSON  MJ Stead  PERSON
# 120: "Lori Toma" is a PERSON
# The most common NER type to "Lori Toma" is PERSON
# 120: "Lori Toma" is a PERSON  Lori Toma  PERSON
# 121: "Nancy Horsfall Couldwell" is a PERSON
# The most common NER type to "Nancy Horsfall Couldwell" is PERSON
# 121: "Nancy Horsfall Couldwell" is a PERSON  Nancy Horsfall Couldwell  PERSON
# 122: "Cochrane" is a ORG
# The most common NER type to "Cochrane" is ORG
# 122: "Cochrane" is a ORG  Cochrane  ORG
# 123: "Alta" is a ORG
# The most common NER type to "Alta" is ORG
# 123: "Alta" is a ORG  Alta  ORG
# 124: "MJ Stead" is a PERSON
# The most common NER type to "MJ Stead" is PERSON
# 124: "MJ Stead" is a PERSON  MJ Stead  PERSON
# 125: "Facebook" is a PRODUCT
# The most common NER type to "Facebook" is PRODUCT
# 125: "Facebook" is a PRODUCT  Facebook  PRODUCT
# 126: "Stead" is a PERSON
# The most common NER type to "Stead" is PERSON
# 126: "Stead" is a PERSON  MJ Stead  PERSON
# 127: "hour-long" is a TIME
# The most common NER type to "hour-long" is TIME
# 127: "hour-long" is a TIME  hour-long  TIME
# 128: "Facebook Live" is a PRODUCT
# The most common NER type to "Facebook Live" is PRODUCT
# 128: "Facebook Live" is a PRODUCT  Facebook Live  PRODUCT
# 129: "20" is a CARDINAL
# The most common NER type to "20" is DATE
# 129: "20" is a CARDINAL  2008  DATE
# 130: "30" is a CARDINAL
# The most common NER type to "30" is CARDINAL
# 130: "30" is a CARDINAL  30  CARDINAL
# 131: "more than 1,500" is a CARDINAL
# The most common NER type to "more than 1,500" is CARDINAL
# 131: "more than 1,500" is a CARDINAL  more than 1,500  CARDINAL
# 132: "more than one" is a CARDINAL
# The most common NER type to "more than one" is CARDINAL
# 132: "more than one" is a CARDINAL  more than one  CARDINAL
# 133: "Two years ago" is a DATE
# The most common NER type to "Two years ago" is DATE
# 133: "Two years ago" is a DATE  Two years ago  DATE
# 134: "Stead" is a PERSON
# The most common NER type to "Stead" is PERSON
# 134: "Stead" is a PERSON  Stead  PERSON
# 135: "100 days" is a DATE
# The most common NER type to "100 days" is DATE
# 135: "100 days" is a DATE  100 days  DATE
# 136: "COVID-19" is a ORG
# The most common NER type to "COVID-19" is ORG
# 136: "COVID-19" is a ORG  COVID-19  ORG
# 137: "Canada" is a GPE
# The most common NER type to "Canada" is ORG
# 137: "Canada" is a GPE  Canada  GPE
# 138: "CBC News" is a ORG
# The most common NER type to "CBC News" is ORG
# 138: "CBC News" is a ORG  CBC News  ORG
# 139: "daily" is a DATE
# The most common NER type to "daily" is DATE
# 139: "daily" is a DATE  daily  DATE
# 140: "CBC News Network" is a ORG
# The most common NER type to "CBC News Network" is ORG
# 140: "CBC News Network" is a ORG  CBC News Network  ORG
# 141: "CBC News Network" is a ORG
# The most common NER type to "CBC News Network" is ORG
# 141: "CBC News Network" is a ORG  CBC News Network  ORG
# 142: "CBC" is a ORG
# The most common NER type to "CBC" is ORG
# 142: "CBC" is a ORG  CBC News Network  ORG
# 143: "CBC News Network" is a ORG
# The most common NER type to "CBC News Network" is ORG
# 143: "CBC News Network" is a ORG  CBC News Network  ORG
# 144: "CBC News" is a ORG
# The most common NER type to "CBC News" is ORG
# 144: "CBC News" is a ORG  CBC News Network  ORG
# 145: "NaN" is a DATE
# The most common NER type to "NaN" is DATE
# 145: "NaN" is a DATE  NaN  DATE

# %% [markdown]
# **ANSWER Q5(b)**
# This method are helpful to get the result, but there are still some conflict.
#
#
# It determint "Canada" is a GPE, but the most common NER type to "Canada" is ORG, and the normolize result for "Canada" GPE is Air Canada ORG.
#
# It determint "the University of Calgary" is a ORG, but the most common NER type to "the University of Calgary" is GPE. The normallize result for "the University of Calgary" is a ORG  the University of Calgary  ORG.

# %% [markdown]
# **PART 3 - Entity Linking / Text enhancement**
#
# For the third part of this notebook, we will be exploring how we can enhance the text of documents. In this scenario, we will be enhancing the text by performing entity linking. This means that we will attempt the linking of the entities that are detected by spaCy's NER to an active webpage that a reader can click on to obtain more information regarding the entity. Wikipedia, is a very good resource to find out more information about an entity, and we will use this resource for entity linking.
#
# Before going straight into an example through code, below is an example of how a text with no entity linking compares to a text with entity linking:
#
# *No entity linking:* \
# During the pandemic, U.S. cities such as Atlanta, Chicago and Denver have made several adjustments to their transit systems.
#
# *With entity linking:*  \
# During the pandemic, U.S. cities such as <a href="http://en.wikipedia.org/wiki/Atlanta">Atlanta</a>, <a href="http://en.wikipedia.org/wiki/Chicago">Chicago</a> and <a href="http://en.wikipedia.org/wiki/Denver">Denver</a> have made several adjustments to their transit systems.

# %% [markdown]
# Transforming a text automatically with clickable links requires several processing at the character string level. In this Notebook, we will be satisfied with finding the links without making the replacements directly in the text. This will allow us to explore the Wikipedia resource, and understand the difficulties relating to "entity linking" without wasting too much time in the complex manipulation of strings.
#
# For example, with the document (index 6), we would like to be able to link the entities found by spaCy to the most likely wikipedia page giving access to additional information on that entity.
#
# **This enriched list format shown is the type of output requested in question Q6 below.**  For coding simplicity, we will use this type of output instead of an article in which the text would replaced by links.
#
# 0: "Coronavirus Brief" is a ORG found at http://en.wikipedia.org/wiki/Coronavirus_Brief \
# 1: "CBC" is a ORG found at http://en.wikipedia.org/wiki/CBC \
# 2: "Canada" is a GPE found at http://en.wikipedia.org/wiki/Canada \
# 3: "C.D. Howe" is a PERSON found at http://en.wikipedia.org/wiki/C.D._Howe \
# 4: ... \

# %% [markdown]
# **(TO DO) Q6 - 5 marks**
# Write the code needed to search a wikipedia page for the entities found by spaCy (as shown above) in a particular document.
#
# *You can write the code as you like, but it must include the following elements:*
#
# *   (a) A restriction on which type of entities you are linking.  For example, Wikipedia does not contain quantities (such as "two meters") so it would be inappropriate to include a link to a quantity.
# *   (b) The use of the *normalized form* of the entity to perform the linking.  For example, *Allison McGeer* does have a Wikipedia page (https://en.wikipedia.org/wiki/Allison_McGeer) that you can link to, even when you are looking at the entity with label *McGeer*.  So make sure to use the function you developed in Q4.
# *   (c) Attention:  the wikipedia page uses underscores. So for example, *McMaster University* should be transformed to https://en.wikipedia.org/wiki/McMaster_University (with an underscore between *McMaster* and *University*
# *   (d) Include one element of post-processing on the longer form.  For example *the C.D. Howe Institute's* is tagged by spaCy, but Wikipedia will contain *C.D._Howe_Institute*.  You can remove small particules like *the* to augment the chance of linking.
# *   (e) For a specific document, output the surface form, entity type and link to Wikipedia in a list as shown above
#
# Be sure to put comments in your code to make it clear what corresponds to parts (a), (b), (c), (d) and (e).
#
# There will be probably many links that you include that will link to wikipedia pages that do not exist.  That's ok, don't worry about that.  Wikipedia does not contain everything, and some normalized forms will not be there.  You will be asked to discuss this later in Q7.

# %%
# ANSWER - Q6
doc = df["text"][6]
doc_sp = sp(doc)
# Display all entities from the text along with their index in the .ents iterator and the
# corresponding NER type
for i, token in enumerate(doc_sp.ents):
    if (token.label_ ==  'GPE' or token.label_ ==  'PERSON' or token.label_ ==  'ORG' or token.label_ ==  'NORP'):
        ent = assign_normalized_form(doc_sp.ents[i], doc_sp.ents[0:i-1])
        if('the' in ent.text):
            after_process = ent.text.replace('the','')
        else:
            after_process = ent.text
        ans1 = after_process.lstrip()
        ans = ans1.replace(' ','_')
        #print("The most common NER type to \"" + doc_sp.ents[i].text + "\" is " + most_common_type(doc_sp.ents[i], doc_sp.ents))
        print(str(i) + ": \"" + ent.text + "\" is a " + ent.label_ + " found at https://en.wikipedia.org/wiki/" + ans)
# Out:
# 0: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 1: "C.D. Howe" is a ORG found at https://en.wikipedia.org/wiki/C.D._Howe
# 2: "Ontario" is a PERSON found at https://en.wikipedia.org/wiki/Ontario
# 4: "Alberta" is a GPE found at https://en.wikipedia.org/wiki/Alberta
# 7: "Air Canada" is a ORG found at https://en.wikipedia.org/wiki/Air_Canada
# 10: "England" is a GPE found at https://en.wikipedia.org/wiki/England
# 11: "Peter Cziborra/Reuters" is a PERSON found at https://en.wikipedia.org/wiki/Peter_Cziborra/Reuters
# 13: "CBC" is a ORG found at https://en.wikipedia.org/wiki/CBC
# 14: "Andre Mayer" is a PERSON found at https://en.wikipedia.org/wiki/Andre_Mayer
# 15: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 17: "cholera" is a ORG found at https://en.wikipedia.org/wiki/cholera
# 19: "Calgary" is a GPE found at https://en.wikipedia.org/wiki/Calgary
# 20: "John Brown" is a PERSON found at https://en.wikipedia.org/wiki/John_Brown
# 21: "the University of Calgary" is a ORG found at https://en.wikipedia.org/wiki/University_of_Calgary
# 24: "Italian" is a NORP found at https://en.wikipedia.org/wiki/Italian
# 25: "Milan" is a GPE found at https://en.wikipedia.org/wiki/Milan
# 27: "Berlin" is a GPE found at https://en.wikipedia.org/wiki/Berlin
# 28: "Budapest" is a GPE found at https://en.wikipedia.org/wiki/Budapest
# 29: "Mexico City" is a GPE found at https://en.wikipedia.org/wiki/Mexico_City
# 30: "Ahsan Habib" is a PERSON found at https://en.wikipedia.org/wiki/Ahsan_Habib
# 31: "Dalhousie University" is a ORG found at https://en.wikipedia.org/wiki/Dalhousie_University
# 32: "U.S." is a GPE found at https://en.wikipedia.org/wiki/U.S.
# 33: "Atlanta" is a GPE found at https://en.wikipedia.org/wiki/Atlanta
# 34: "Chicago" is a GPE found at https://en.wikipedia.org/wiki/Chicago
# 35: "Denver" is a GPE found at https://en.wikipedia.org/wiki/Denver
# 36: "Ahsan Habib" is a PERSON found at https://en.wikipedia.org/wiki/Ahsan_Habib
# 37: "John Brown" is a PERSON found at https://en.wikipedia.org/wiki/John_Brown
# 38: "Calgary" is a GPE found at https://en.wikipedia.org/wiki/Calgary
# 39: "Housebrand" is a ORG found at https://en.wikipedia.org/wiki/Housebrand
# 41: "Quebec" is a GPE found at https://en.wikipedia.org/wiki/Quebec
# 42: "Conservative" is a NORP found at https://en.wikipedia.org/wiki/Conservative
# 43: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 44: "C.D. Howe" is a ORG found at https://en.wikipedia.org/wiki/C.D._Howe
# 45: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 46: "the C.D. Howe Institute's" is a ORG found at https://en.wikipedia.org/wiki/C.D._Howe_Institute's
# 47: "Business Cycle Council" is a ORG found at https://en.wikipedia.org/wiki/Business_Cycle_Council
# 49: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 55: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 57: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 62: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 64: "Alberta" is a GPE found at https://en.wikipedia.org/wiki/Alberta
# 69: "Doug Ford" is a PERSON found at https://en.wikipedia.org/wiki/Doug_Ford
# 70: "Alberta" is a GPE found at https://en.wikipedia.org/wiki/Alberta
# 71: "Jason Kenney" is a PERSON found at https://en.wikipedia.org/wiki/Jason_Kenney
# 73: "Alberta" is a GPE found at https://en.wikipedia.org/wiki/Alberta
# 76: "Kenney" is a ORG found at https://en.wikipedia.org/wiki/Kenney
# 80: "Kenney" is a ORG found at https://en.wikipedia.org/wiki/Kenney
# 82: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 84: "Air Canada" is a ORG found at https://en.wikipedia.org/wiki/Air_Canada
# 85: "Canadians" is a NORP found at https://en.wikipedia.org/wiki/Canadians
# 86: "Tim Strauss" is a PERSON found at https://en.wikipedia.org/wiki/Tim_Strauss
# 87: "Canadians" is a NORP found at https://en.wikipedia.org/wiki/Canadians
# 88: "Air Canada" is a ORG found at https://en.wikipedia.org/wiki/Air_Canada
# 90: "Canadian Club Toronto" is a ORG found at https://en.wikipedia.org/wiki/Canadian_Club_Toronto
# 92: "North American" is a NORP found at https://en.wikipedia.org/wiki/North_American
# 93: "Air Canada" is a ORG found at https://en.wikipedia.org/wiki/Air_Canada
# 94: "Sunwing and American Airlines" is a ORG found at https://en.wikipedia.org/wiki/Sunwing_and_American_Airlines
# 95: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 97: "Air Canada" is a ORG found at https://en.wikipedia.org/wiki/Air_Canada
# 99: "Helane Becker" is a PERSON found at https://en.wikipedia.org/wiki/Helane_Becker
# 101: "Helane Becker" is a PERSON found at https://en.wikipedia.org/wiki/Helane_Becker
# 102: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 103: "CBC News" is a ORG found at https://en.wikipedia.org/wiki/CBC_News
# 104: "U.S." is a GPE found at https://en.wikipedia.org/wiki/U.S.
# 105: "U.S." is a GPE found at https://en.wikipedia.org/wiki/U.S.
# 106: "Anthony Fauci" is a PERSON found at https://en.wikipedia.org/wiki/Anthony_Fauci
# 107: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 108: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 109: "Health Canada" is a ORG found at https://en.wikipedia.org/wiki/Health_Canada
# 110: "Gilead" is a ORG found at https://en.wikipedia.org/wiki/Gilead
# 111: "CBC News" is a ORG found at https://en.wikipedia.org/wiki/CBC_News
# 112: "Gilead" is a ORG found at https://en.wikipedia.org/wiki/Gilead
# 113: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 114: "Alberta" is a GPE found at https://en.wikipedia.org/wiki/Alberta
# 116: "Grace Horsfall Couldwell" is a PERSON found at https://en.wikipedia.org/wiki/Grace_Horsfall_Couldwell
# 118: "Alberta" is a GPE found at https://en.wikipedia.org/wiki/Alberta
# 119: "MJ Stead" is a PERSON found at https://en.wikipedia.org/wiki/MJ_Stead
# 120: "Lori Toma" is a PERSON found at https://en.wikipedia.org/wiki/Lori_Toma
# 121: "Nancy Horsfall Couldwell" is a PERSON found at https://en.wikipedia.org/wiki/Nancy_Horsfall_Couldwell
# 122: "Cochrane" is a ORG found at https://en.wikipedia.org/wiki/Cochrane
# 123: "Alta" is a ORG found at https://en.wikipedia.org/wiki/Alta
# 124: "MJ Stead" is a PERSON found at https://en.wikipedia.org/wiki/MJ_Stead
# 126: "MJ Stead" is a PERSON found at https://en.wikipedia.org/wiki/MJ_Stead
# 134: "MJ Stead" is a PERSON found at https://en.wikipedia.org/wiki/MJ_Stead
# 136: "COVID-19" is a ORG found at https://en.wikipedia.org/wiki/COVID-19
# 137: "Canada" is a GPE found at https://en.wikipedia.org/wiki/Canada
# 138: "CBC News" is a ORG found at https://en.wikipedia.org/wiki/CBC_News
# 140: "CBC News Network" is a ORG found at https://en.wikipedia.org/wiki/CBC_News_Network
# 141: "CBC News Network" is a ORG found at https://en.wikipedia.org/wiki/CBC_News_Network
# 142: "CBC News Network" is a ORG found at https://en.wikipedia.org/wiki/CBC_News_Network
# 143: "CBC News Network" is a ORG found at https://en.wikipedia.org/wiki/CBC_News_Network
# 144: "CBC News Network" is a ORG found at https://en.wikipedia.org/wiki/CBC_News_Network

# %% [markdown]
# **(TO DO) Q7 - 5 marks**
# Perform a qualitative evaluation of the entity linking method you wrote in Q6.  For your qualitative evaluation, you must choose a document (any one you want from the corpus of covid-19 related news, but make sure to mention which one) and run your method on that document.  Answer the following questions :
#
# * a. Give 2 examples of entities where the longer form was found in Wikipedia.  Is the page found appropriate? Would the shorter form be found too? Would it link to the same page?
# * b.  Give 2 examples of entities where the wikipedia page did not exist.  Why is that?  Was the form searched on incorrect?
# * c.  Try restricting your search with different entity types.  Do you see DATE covered by Wikipedia?  What about PERSON or GPE?  Discuss the coverage of different entity types by giving some examples.

# %%
doc = df["text"][1]
doc_sp = sp(doc)
# Display all entities from the text along with their index in the .ents iterator and the
# corresponding NER type
for i, token in enumerate(doc_sp.ents):
    if (token.label_ ==  'GPE' or token.label_ ==  'PERSON' or token.label_ ==  'ORG' or token.label_ ==  'NORP'):
        ent = assign_normalized_form(doc_sp.ents[i], doc_sp.ents[0:i-1])
        if('the' in ent.text):
            after_process = ent.text.replace('the','')
        else:
            after_process = ent.text
        ans1 = after_process.lstrip()
        ans = ans1.replace(' ','_')
        #print("The most common NER type to \"" + doc_sp.ents[i].text + "\" is " + most_common_type(doc_sp.ents[i], doc_sp.ents))
        print(str(i) + ": \"" + token.text + "\" is a " + ent.label_ + "found at https://en.wikipedia.org/wiki/"+ans)
        #print(str(i) + ": \"" + token.text + "\" is a " + token.label_ + "  " + ent.text + "  " + ent.label_)
# Out:
# 4: "COVID-19" is a PERSONfound at https://en.wikipedia.org/wiki/COVID-19
# 5: "the World Health Organization" is a ORGfound at https://en.wikipedia.org/wiki/World_Health_Organization
# 6: "WHO" is a ORGfound at https://en.wikipedia.org/wiki/WHO
# 8: "the Public Health Agency" is a ORGfound at https://en.wikipedia.org/wiki/Public_Health_Agency
# 9: "Canada" is a GPEfound at https://en.wikipedia.org/wiki/Canada
# 15: "W.F. Wells" is a PERSONfound at https://en.wikipedia.org/wiki/W.F._Wells
# 16: "the Harvard School of Public Health" is a ORGfound at https://en.wikipedia.org/wiki/Harvard_School_of_Public_Health
# 18: "Wells" is a ORGfound at https://en.wikipedia.org/wiki/Wells
# 20: "Canada" is a GPEfound at https://en.wikipedia.org/wiki/Canada
# 22: "Lydia Bourouiba" is a PERSONfound at https://en.wikipedia.org/wiki/Lydia_Bourouiba
# 23: "the Fluid Dynamics of Disease Transmission Laboratory" is a ORGfound at https://en.wikipedia.org/wiki/Fluid_Dynamics_of_Disease_Transmission_Laboratory
# 24: "the Massachusetts Institute of Technology" is a ORGfound at https://en.wikipedia.org/wiki/Massachusetts_Institute_of_Technology
# 25: "Bourouiba" is a PERSONfound at https://en.wikipedia.org/wiki/Lydia_Bourouiba
# 26: "Canadian" is a NORPfound at https://en.wikipedia.org/wiki/Canadian
# 27: "Mark Loeb" is a PERSONfound at https://en.wikipedia.org/wiki/Mark_Loeb
# 28: "McMaster University" is a ORGfound at https://en.wikipedia.org/wiki/McMaster_University
# 29: "RNA" is a ORGfound at https://en.wikipedia.org/wiki/RNA
# 30: "Wuhan" is a GPEfound at https://en.wikipedia.org/wiki/Wuhan
# 31: "China" is a GPEfound at https://en.wikipedia.org/wiki/China
# 32: "Nebraska" is a GPEfound at https://en.wikipedia.org/wiki/Nebraska
# 33: "Canada" is a GPEfound at https://en.wikipedia.org/wiki/Canada
# 35: "COVID-19" is a ORGfound at https://en.wikipedia.org/wiki/COVID-19
# 36: "Gary Moore/CBC" is a PERSONfound at https://en.wikipedia.org/wiki/Gary_Moore/CBC
# 37: "Allison McGeer" is a PERSONfound at https://en.wikipedia.org/wiki/Allison_McGeer
# 38: "Sinai Health" is a ORGfound at https://en.wikipedia.org/wiki/Sinai_Health
# 39: "Toronto" is a GPEfound at https://en.wikipedia.org/wiki/Toronto
# 40: "COVID-19" is a PERSONfound at https://en.wikipedia.org/wiki/COVID-19
# 44: "McGeer" is a ORGfound at https://en.wikipedia.org/wiki/McGeer
# 46: "McGeer" is a ORGfound at https://en.wikipedia.org/wiki/McGeer
# 47: "Bourouiba" is a PERSONfound at https://en.wikipedia.org/wiki/Lydia_Bourouiba
# 48: "Bourouiba" is a PERSONfound at https://en.wikipedia.org/wiki/Lydia_Bourouiba
# 51: "Credit Lydia Bourouiba/MIT/JAMA Networks" is a ORGfound at https://en.wikipedia.org/wiki/Credit_Lydia_Bourouiba/MIT/JAMA_Networks
# 52: "Canadian" is a NORPfound at https://en.wikipedia.org/wiki/Canadian
# 56: "Samira Mubareka" is a PERSONfound at https://en.wikipedia.org/wiki/Samira_Mubareka
# 58: "Toronto" is a GPEfound at https://en.wikipedia.org/wiki/Toronto
# 60: "Bourouiba" is a PERSONfound at https://en.wikipedia.org/wiki/Lydia_Bourouiba
# 68: "COVID-19" is a ORGfound at https://en.wikipedia.org/wiki/COVID-19
# 69: "McMaster" is a PERSONfound at https://en.wikipedia.org/wiki/McMaster
# 70: "N95" is a ORGfound at https://en.wikipedia.org/wiki/N95
# 71: "U.S." is a GPEfound at https://en.wikipedia.org/wiki/U.S.
# 72: "Canadian" is a NORPfound at https://en.wikipedia.org/wiki/Canadian
# 73: "Justin Trudeau" is a PERSONfound at https://en.wikipedia.org/wiki/Justin_Trudeau
# 74: "Mubareka" is a PERSONfound at https://en.wikipedia.org/wiki/Samira_Mubareka
# 76: "the New England Journal of Medicine" is a ORGfound at https://en.wikipedia.org/wiki/New_England_Journal_of_Medicine
# 77: "the U.S. National Institutes of Health" is a ORGfound at https://en.wikipedia.org/wiki/U.S._National_Institutes_of_Health
# 79: "U.S. National Institutes of Health" is a ORGfound at https://en.wikipedia.org/wiki/U.S._National_Institutes_of_Health
# 81: "COVID-19?" is a ORGfound at https://en.wikipedia.org/wiki/COVID-19?
# 83: "Journal of the Royal Society Interface" is a ORGfound at https://en.wikipedia.org/wiki/Journal_of__Royal_Society_Interface
# 85: "U.S." is a GPEfound at https://en.wikipedia.org/wiki/U.S.
# 86: "Singapore" is a GPEfound at https://en.wikipedia.org/wiki/Singapore
# 87: "N95" is a ORGfound at https://en.wikipedia.org/wiki/N95
# 88: "Gary S. Settles" is a PERSONfound at https://en.wikipedia.org/wiki/Gary_S._Settles
# 89: "Penn State University/Journal of the Royal Society Interface" is a ORGfound at https://en.wikipedia.org/wiki/Penn_State_University/Journal_of__Royal_Society_Interface
# 90: "The World Health Organization" is a ORGfound at https://en.wikipedia.org/wiki/The_World_Health_Organization
# 91: "Los Angeles" is a GPEfound at https://en.wikipedia.org/wiki/Los_Angeles
# 92: "Italy" is a GPEfound at https://en.wikipedia.org/wiki/Italy
# 93: "Austria" is a GPEfound at https://en.wikipedia.org/wiki/Austria

# %% [markdown]
# **ANSWER Q7**
# a)I choose document 2. For example, for WHO and World Health Organization. They both point to the same website. Also,Bourouiba and Lydia Bourouiba also point to the same website
#
# b)Grace Horsfall Couldwell can not be found in wiki website, because she is not a famous person.
#  Also, N95 can not be found found in website, because it need more infomation, it is a kind of mask.

# %% [markdown]
# ***SIGNATURE:***
# My name is Tan Chen.
# My student number is 300072995.
# I certify being the author of this assignment.
